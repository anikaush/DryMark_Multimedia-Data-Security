# %%
from sys import argv
from time import time
from noiseprint.noiseprint import genNoiseprint
from noiseprint.utility.utilityRead import imread2f
from noiseprint.utility.utilityRead import jpeg_qtableinv
import numpy as np
import cv2
# Out:
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\noiseprint.py:24: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\noiseprint.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\network.py:44: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\network.py:108: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\network.py:111: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\network.py:97: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\noiseprint.py:27: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\noiseprint.py:29: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
imgfilename = 'C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\dev-dataset-forged\\dev_0414.tif'
outfilename = 'out'

timestamp = time()
img, mode = imread2f(imgfilename, channel=1)
try:
    QF = jpeg_qtableinv(strimgfilenameeam)
except:
    QF = 200
    
res = genNoiseprint(img,QF)
timeApproach = time() - timestamp

out_dict = dict()
out_dict['noiseprint'] = res
out_dict['QF'] = QF
out_dict['time'] = timeApproach

if outfilename[-4:] == '.mat':
    import scipy.io as sio
    sio.savemat(outfilename, out_dict)
else:
    import numpy as np
    np.savez(outfilename, **out_dict)
# Out:
# WARNING:tensorflow:From C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\noiseprint.py:36: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model

# %%
import pickle
import numpy as numpy
file = open('store.pckl', 'rb')
prev_prnus = pickle.load(file)

# %%
import math
def mean2(x):
    y = np.sum(x) / np.size(x);
    return y

def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / math.sqrt((a*a).sum() * (b*b).sum());
    return r

# %%
def get_camera_prnu(camera_nr: int) -> np.ndarray:
    path = 'C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\'
    index = '000'
    noises = []
    
    for i in range(100):
        index ="%03d" % (i+1)
        img, mode = imread2f(path + 'flat-camera-'+ str(camera_nr) + '\\flat_c'+ str(camera_nr) + '_' + index + '.tif', channel=1)
        try:
            QF = jpeg_qtableinv(strimgfilenameeam)
        except:
            QF = 200

        res = genNoiseprint(img,QF)
        noises.append(res)
        print(i)
      
    final = numpy.mean(noises,0)
    return final

# %%
prnu1 = get_camera_prnu(1)
f = open('prnu1_cnn.pckl', 'wb')
pickle.dump(prnu1, f)
f.close()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 0
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 1
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 2
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 3
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 4
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 5
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 6
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 7
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 8
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 9
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 10
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 11
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 12
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 13
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 14
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 15
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 16
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 17
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 18
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 19
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 20
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 21
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 22
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 23
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 24
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 25
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 26
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 27
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 28
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 29
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 30
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 31
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 32
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 33
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 34
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 35
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 36
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 37
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 38
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 39
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 40
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 41
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 42
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 43
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 44
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 45
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 46
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 47
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 48
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 49
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 50
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 51
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 52
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 53
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 54
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 55
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 56
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 57
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 58
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 59
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 60
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 61
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 62
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 63
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 64
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 65
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 66
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 67
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 68
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 69
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 70
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 71
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 72
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 73
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 74
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 75
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 76
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 77
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 78
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 79
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 80
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 81
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 82
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 83
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 84
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 85
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 86
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 87
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 88
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 89
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 90
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 91
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 92
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 93
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 94
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 95
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 96
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 97
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 98
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 99

# %%
prnu2 = get_camera_prnu(2)
f = open('prnu2_cnn.pckl', 'wb')
pickle.dump(prnu2, f)
f.close()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 0
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 1
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 2
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 3
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 4
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 5
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 6
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 7
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 8
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
# 9
# INFO:tensorflow:Restoring parameters from C:\Users\rotar\OneDrive\Desktop\Master\UNITN\Semester 1\Multimedia Data Security\2nd Competition\PRNU\noiseprint\./nets/net_jpg101/model
#  1500x2000 large 101
#
import numpy as np
from PIL import Image
import pywt
from numpy.fft import fft2, ifft2
from scipy.ndimage import filters
from sklearn.metrics import roc_curve, auc
from tqdm import tqdm

im = Image.open('C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\dev-dataset-forged\\dev_0001.tif')


imarray = np.array(im)

print(type(imarray))

noise = noise_extract(imarray)

# %%
from PIL import Image
filename = '../dev-dataset/dev-dataset-forged\dev_0002.jpg'

try:
    test_prnus_file = open('test_prnus.pckl', 'rb')
    test_prnus = pickle.load(test_prnus_file)
except:
    test_prnus = {}

if(filename in test_prnus):
    noise = test_prnus[filename]
else:
    img, _ = imread2f(filename)
    noise = genNoiseprint(img,200)
    test_prnus[filename] = noise
    file_write = open('test_prnus.pckl', 'wb')
    pickle.dump(test_prnus, file_write)
    file_write.close()
        
#img, mode = imread2f('C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\demo_images\\demo_1.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46c1f3eeb6b3> in <module>
#      11     noise = test_prnus[filename]
#      12 else:
# ---> 13     img, _ = imread2f(filename)
#      14     noise = genNoiseprint(img,200)
#      15     test_prnus[filename] = noise
#
# NameError: name 'imread2f' is not defined

# %%
import numpy as np
print(corr2(noise, prev_prnus[0][:,:,1]))
print(corr2(noise, prev_prnus[1][:,:,1]))
print(corr2(noise, prev_prnus[2][:,:,1]))
print(corr2(noise, prev_prnus[3][:,:,1]))
# Out:
# 0.0011467020300461159
# 0.00027548212988436847
# 0.0015411458429533697
# 0.017179568291693224

# %%
def get_map(prnu : np.ndarray or list, noise: np.ndarray or list) -> np.ndarray:
    
    diff_map = numpy.zeros_like(prnu)
    for i in range(len(prnu)):
        for j in range(len(prnu[0])):
            diff_map[i][j] = abs(prnu[i][j] - noise[i][j]) * 75
            
    return diff_map

# %%
def is_inside(i: int, j: int, rows: int, cols: int):
    if (i>=0 and j >=0 and i<rows and j<cols): return True
    return False

# %%
def get_map_segment(prnu : np.ndarray or list, noise: np.ndarray or list, rows: int, cols: int, thr: float, clear: bool) -> np.ndarray:
    row_inc = prnu.shape[0]/rows
    col_inc = prnu.shape[1]/cols
    
    avg = np.average(np.absolute(prnu-noise))
    
    diff_map = diff_map = np.zeros_like(prnu, np.uint8)
    for i in range(rows):
        for j in range(cols):
            i1 = int(i*row_inc)
            i2 = int((i+1)*row_inc)
            j1 = int(j*col_inc)
            j2 = int((j+1)*col_inc)
            
            m = np.mean(np.absolute(prnu[i1:i2, j1:j2] - noise[i1:i2, j1:j2]))
            if(m > avg*1.1):
                diff_map[i1:i2, j1:j2].fill(255)
            else:
                diff_map[i1:i2, j1:j2].fill(0)
                
    if(clear):
        for i in range(rows):
            for j in range(cols):
                i1 = int(i*row_inc)
                i2 = int((i+1)*row_inc)
                j1 = int(j*col_inc)
                j2 = int((j+1)*col_inc)

                if(is_inside(i1-1,j1, prnu.shape[0], prnu.shape[1]) and diff_map[i1-1][j1] != diff_map[i1][j1] and 
                   is_inside(i2+1,j1, prnu.shape[0], prnu.shape[1]) and diff_map[i2+1][j1] != diff_map[i1][j1] and 
                   is_inside(i1,j2+1, prnu.shape[0], prnu.shape[1]) and diff_map[i1][j2+1] != diff_map[i1][j1] and 
                   is_inside(i1,j1-1, prnu.shape[0], prnu.shape[1]) and diff_map[i1][j1-1] != diff_map[i1][j1]):
                    diff_map[i1:i2, j1:j2].fill(abs(diff_map[i1][j1] - 255))
            
    return diff_map

# %%
diff = get_map_segment(noise, prnu3, 150, 200, 0.5, True )
#diff = get_map(noise, prnu4)
diff = cv2.medianBlur(diff, 17)
img = Image.fromarray(diff)
img.show()

# %%
kernel = np.ones((29,29),np.uint8)
kernel1 = np.ones((13,13),np.uint8)
#erosion = cv2.erode(diff,kernel,iterations = 2)
erosion = cv2.erode(diff,kernel1,iterations = 1)
erosion = cv2.dilate(erosion,kernel1,iterations = 1)
erosion = cv2.dilate(erosion,kernel,iterations = 2)
erosion = cv2.erode(erosion,kernel,iterations = 2)
img = Image.fromarray(erosion)
img.show()
#cv2.imshow("res", diff)

# %%
def inverse_bits(temper_map) -> np.ndarray:
    return np.absolute(temper_map - 255)*255

# %%
import imageio 
import numpy as np



def f_measure(map_gt,map_est):
    if not map_gt.shape == map_est.shape:
        print('The compared maps must have the same size')

    # Vectorize maps
    map_gt = np.ndarray.flatten(map_gt)
    map_est = np.ndarray.flatten(map_est)

    # Number of pixels
    N = map_gt.size
    # Indices of forged pixels in the ground truth
    i_pos = np.where(map_gt == 1)
    # Number of forged pixels in the ground truth
    n_pos = map_gt[i_pos].shape[0]

    # True Positive Rate: fraction of forged pixels correctly identified as forged
    tp = np.where(map_gt[i_pos]==map_est[i_pos])[0].shape[0]
    tpr = tp / n_pos
    # False Negative Rate: fraction of forged pixels wrongly identified as non-forged
    fn = n_pos-tp
    fnr = fn / n_pos
    # False Positive Rate: fraction of non-forged pixels wrongly identified as forged
    # Indices of non-forged pixels in the ground truth
    i_neg = np.where(map_gt == 0)
    fp = np.where(map_est[i_neg]==1)[0].shape[0]
    fpr = fp / (N-n_pos)

    F = 2*tp / (2*tp+fn+fp)

    return F, tp, fn, fp

# %%
map_gt = imageio.imread('C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\dev-dataset-maps\\dev_0004.bmp')
map_gt = np.array(map_gt/255,dtype=np.uint8)

#map_est = np.array(erosion/255,dtype=np.uint8)
map_est = np.array(inverse_bits(erosion)/255,dtype=np.uint8)

F,_,_,_ = f_measure(map_gt,map_est)
print(F)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5ee7fc9b6d51> in <module>
# ----> 1 map_gt = imageio.imread('C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\dev-dataset-maps\\dev_0004.bmp')
#       2 map_gt = np.array(map_gt/255,dtype=np.uint8)
#       3
#       4 #map_est = np.array(erosion/255,dtype=np.uint8)
#       5 map_est = np.array(inverse_bits(erosion)/255,dtype=np.uint8)
#
# NameError: name 'imageio' is not defined

# %%
import imageio
map_gt = imageio.imread('C:\\Users\\rotar\\OneDrive\\Desktop\\Master\\UNITN\\Semester 1\\Multimedia Data Security\\2nd Competition\\dev-dataset\\dev-dataset-maps\\dev_0004.bmp')

map_gt.shape
# Out:
# (1500, 2000)
